# %%
# import
import json
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 1000)

# %%
df = None
with open('康力泉_record.json','r',encoding='utf-8') as f:
    df = pd.DataFrame([(pd.Series(x)) for x in json.loads(f.read())])
df.to_excel('04_康力泉_支付宝.xlsx', sheet_name=f'康力泉_交易记录')
df
# Out:
#    id        date      time    code       name deal_type  nav_unit  nav_acc  \
# 0   1  2017-11-30  14:03:09  001064  广发中证环保产业A        买入    0.7683   0.7683
# 1   2  2018-02-02  14:27:41  001064  广发中证环保产业A        买入    0.6987   0.6987
# 2   3  2018-04-26  14:09:17  001064  广发中证环保产业A        买入    0.6872   0.6872
#
#     volume  deal_money   fee  occur_money account category1 category2  \
# 0  5200.07     3995.21  4.79       4000.0     支付宝       A 股       行业股
# 1  5718.06     3995.21  4.79       4000.0     支付宝       A 股       行业股
# 2  5813.75     3995.21  4.79       4000.0     支付宝       A 股       行业股
#
#   category3  category_id note
# 0      中证环保          143    无
# 1      中证环保          143    无
# 2      中证环保          143    无
